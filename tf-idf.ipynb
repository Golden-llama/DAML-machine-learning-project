# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('nopunctANDstopwords.csv')

# %%
vectorizer = TfidfVectorizer(
    max_features=10000,    
    ngram_range=(1, 2),
)

# %%
df['text'] = df['text'].fillna('').astype(str)
tfidf_matrix = vectorizer.fit_transform(df['text'])

tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=vectorizer.get_feature_names_out()
)
#df_tfidf = pd.concat([df.reset_index(drop=True), tfidf_df.reset_index(drop=True)], axis=1)

df_tfidf.to_csv('tfidf_dataset.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 df['text'] = df['text'].fillna('').astype(str)
# ----> 2 tfidf_matrix = vectorizer.fit_transform(df['text'])
#       4 tfidf_df = pd.DataFrame(
#       5     tfidf_matrix.toarray(),
#       6     columns=vectorizer.get_feature_names_out()
#       7 )
#       8 #df_tfidf = pd.concat([df.reset_index(drop=True), tfidf_df.reset_index(drop=True)], axis=1)
#
# File ~/Documents/DAML/DAML-machine-learning-project/venv/lib/python3.14/site-packages/sklearn/feature_extraction/text.py:2105, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2098 self._check_params()
#    2099 self._tfidf = TfidfTransformer(
#    2100     norm=self.norm,
#    2101     use_idf=self.use_idf,
#    2102     smooth_idf=self.smooth_idf,
#    2103     sublinear_tf=self.sublinear_tf,
#    2104 )
# -> 2105 X = super().fit_transform(raw_documents)
#    2106 self._tfidf.fit(X)
#    2107 # X is already a transformed view of raw_documents so
#    2108 # we set copy to False
#
# File ~/Documents/DAML/DAML-machine-learning-project/venv/lib/python3.14/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/DAML/DAML-machine-learning-project/venv/lib/python3.14/site-packages/sklearn/feature_extraction/text.py:1377, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1369             warnings.warn(
#    1370                 "Upper case characters found in"
#    1371                 " vocabulary while 'lowercase'"
#    1372                 " is True. These entries will not"
#    1373                 " be matched with any documents"
#    1374             )
#    1375             break
# -> 1377 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1379 if self.binary:
#    1380     X.data.fill(1)
#
# File ~/Documents/DAML/DAML-machine-learning-project/venv/lib/python3.14/site-packages/sklearn/feature_extraction/text.py:1268, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1266 feature_idx = vocabulary[feature]
#    1267 if feature_idx not in feature_counter:
# -> 1268     feature_counter[feature_idx] = 1
#    1269 else:
#    1270     feature_counter[feature_idx] += 1
#
# KeyboardInterrupt:
